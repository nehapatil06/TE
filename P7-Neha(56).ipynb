# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\admin\anaconda3\lib\site-packages (3.9.4)
# Requirement already satisfied: click in c:\users\admin\anaconda3\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\admin\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\admin\anaconda3\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\admin\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
nltk.data.path.append('Desktop')

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.tokenize import sent_tokenize

text = """Hello Mr.smith,how are you doing today? The weather is great, and city is awesome. The sky is pinkish-blue. You shouldn't eat cardboard"""
print(sent_tokenize(text))
# Out:
# ['Hello Mr.smith,how are you doing today?', 'The weather is great, and city is awesome.', 'The sky is pinkish-blue.', "You shouldn't eat cardboard"]
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['Hello', 'Mr.smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'city', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard']

# %%
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_word)
print(fdist)
# Out:
# <FreqDist with 24 samples and 29 outcomes>

# %%
fdist.most_common(2)
# Out:
# [('is', 3), (',', 2)]

# %%
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
print(stop_words)
# Out:
# {'these', 'there', 'd', 'where', 'won', 'during', 'me', 'that', "we're", 'each', "hadn't", 'what', 'because', 'in', 'been', "they'd", 'doing', 'or', 'be', 'just', "shouldn't", 'through', "don't", "isn't", 'it', 'his', 'o', "weren't", 'does', 'not', 'while', "you'll", 'am', "it'd", 'her', 're', 'below', 'same', 'you', 'how', 'too', 'its', 'out', "i'll", 'nor', 'mustn', "i'd", 'theirs', 'isn', 'until', 'hers', "they've", 'on', 'haven', 'do', 'about', 'from', 'herself', 'for', 'very', "you're", "it'll", 'have', 'over', 'an', "we'd", 'your', 'i', "haven't", 'all', 'yourself', 'is', 'whom', 'of', "mustn't", 'up', 'himself', "she's", 'some', 'm', 'any', 'mightn', 'other', 'to', 'with', 'y', 'weren', 'him', "it's", "mightn't", 'such', 'needn', 'so', 'them', 'after', 'both', 'ain', 'don', 'own', "you'd", 'couldn', 'further', 'our', 'she', 'll', 'was', "hasn't", 'can', 'if', 'yourselves', "aren't", 's', 'ma', 'the', 'when', 'before', "he's", 'my', 'hadn', "didn't", 'ourselves', 'only', 'at', "we've", 'ours', "she'll", 'under', 'then', "needn't", 'and', 'again', "he'd", 'once', 'into', "couldn't", "i've", "you've", 'are', 've', 't', "we'll", 'they', "doesn't", 'yours', 'should', 'has', 'hasn', 'as', 'now', 'those', 'being', 'shouldn', 'he', 'will', 'why', 'we', "i'm", 'above', 'wasn', 'here', 'had', 'myself', "she'd", 'did', "that'll", 'no', 'their', 'more', 'most', "won't", 'shan', "wouldn't", "they'll", 'but', 'doesn', "he'll", 'itself', "wasn't", 'themselves', 'who', 'a', "should've", 'between', 'wouldn', "they're", 'were', 'off', "shan't", 'against', 'aren', 'this', 'few', 'by', 'having', 'which', 'than', 'down', 'didn'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.tokenize import word_tokenize
text1="""Hello Mr.smith,how are you doing today?"""
tokenized_sent=word_tokenize(text1)
print(tokenized_sent)
filtered_sent=[]
for w in tokenized_sent:
    if w not in stop_words:
        filtered_sent.append(w)
print("Tokenized Sentences:",tokenized_sent)
print("Filtered Sentence:",filtered_sent)
# Out:
# ['Hello', 'Mr.smith', ',', 'how', 'are', 'you', 'doing', 'today', '?']
# Tokenized Sentences: ['Hello', 'Mr.smith', ',', 'how', 'are', 'you', 'doing', 'today', '?']
# Filtered Sentence: ['Hello', 'Mr.smith', ',', 'today', '?']

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()

stemmed_words=[]
for w in filtered_sent:
    stemmed_words.append(ps.stem(w))
    
print("Filtered Sentence:",filtered_sent)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['Hello', 'Mr.smith', ',', 'today', '?']
# Stemmed Sentence: ['hello', 'mr.smith', ',', 'today', '?']

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()

from nltk.stem.porter import PorterStemmer
stem = PorterStemmer()

word = "flying"
print("Lemmenized word:",lem.lemmatize(word,"v"))
print("Stemmed word:",stem.stem(word))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Lemmenized word: fly
# Stemmed word: fli

# %%
sent = "Albert Einstein was born in Ulm,Germant in 1879."

# %%
tokens=nltk.word_tokenize(sent)
print(tokens)
# Out:
# ['Albert', 'Einstein', 'was', 'born', 'in', 'Ulm', ',', 'Germant', 'in', '1879', '.']

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
nltk.pos_tag(tokens)
# Out:
# [('Albert', 'NNP'),
#  ('Einstein', 'NNP'),
#  ('was', 'VBD'),
#  ('born', 'VBN'),
#  ('in', 'IN'),
#  ('Ulm', 'NNP'),
#  (',', ','),
#  ('Germant', 'NNP'),
#  ('in', 'IN'),
#  ('1879', 'CD'),
#  ('.', '.')]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
corpus = [
    "Sachin was the GOAT of the previous generation",
    "Virat is the GOAT of the this generation",
    "Shubman will be the GOAT of the next generation"
]
vectorizer = TfidfVectorizer()

# %%
matrix = vectorizer.fit(corpus)
matrix.vocabulary_
# Out:
# {'sachin': 7,
#  'was': 12,
#  'the': 9,
#  'goat': 2,
#  'of': 5,
#  'previous': 6,
#  'generation': 1,
#  'virat': 11,
#  'is': 3,
#  'this': 10,
#  'shubman': 8,
#  'will': 13,
#  'be': 0,
#  'next': 4}

# %%
tfidf_matrix = vectorizer.transform(corpus)
print(tfidf_matrix)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 22 stored elements and shape (3, 14)>
#   Coords	Values
#   (0, 1)	0.25318287697299496
#   (0, 2)	0.25318287697299496
#   (0, 5)	0.25318287697299496
#   (0, 6)	0.4286758743128819
#   (0, 7)	0.4286758743128819
#   (0, 9)	0.5063657539459899
#   (0, 12)	0.4286758743128819
#   (1, 1)	0.25318287697299496
#   (1, 2)	0.25318287697299496
#   (1, 3)	0.42867587431288195
#   (1, 5)	0.25318287697299496
#   (1, 9)	0.5063657539459899
#   (1, 10)	0.42867587431288195
#   (1, 11)	0.42867587431288195
#   (2, 0)	0.39400039808922477
#   (2, 1)	0.23270298212286766
#   (2, 2)	0.23270298212286766
#   (2, 4)	0.39400039808922477
#   (2, 5)	0.23270298212286766
#   (2, 8)	0.39400039808922477
#   (2, 9)	0.4654059642457353
#   (2, 13)	0.39400039808922477

# %%
print(vectorizer.get_feature_names_out())
# Out:
# ['be' 'generation' 'goat' 'is' 'next' 'of' 'previous' 'sachin' 'shubman'
#  'the' 'this' 'virat' 'was' 'will']
